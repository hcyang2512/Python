# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import talib
import statsmodels
import time
from selenium import webdriver
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
driver = webdriver.Chrome('C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\chrome\chromedriver')  # Optional argument, if not specified will search path.
driver.get('https://www.esunbank.com.tw/bank/personal/deposit/rate/forex/exchange-rate-chart?Currency=CNY/TWD');
time.sleep(5) # Let the user actually see something!
pageSource = driver.page_source  # 取得網頁原始碼
print(pageSource)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3e72c6e43a77> in <module>()
#       3 time.sleep(5) # Let the user actually see something!
#       4 pageSource = driver.page_source  # 取得網頁原始碼
# ----> 5 print(pageSource,html.parser)
#       6
#       7 driver.close()
#
# NameError: name 'html' is not defined

# %%
soup = BeautifulSoup(pageSource, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="js flexbox canvas canvastext webgl no-touch geolocation postmessage websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers applicationcache svg inlinesvg smil svgclippaths" style="" xmlns="http://www.w3.org/1999/xhtml">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1000, user-scalable=1" name="viewport"/>
#   <title id="pageTitle">
# ...

# %%
td_tag = soup.select("td.lastTd")
td_tag
tblh=soup.find_all('td')
tdlh
# Out:
# [<td class="lastTd">賣出</td>,
#  <td class="lastTd">4.572</td>,
#  <td class="lastTd">4.59</td>,
#  <td class="lastTd">4.591</td>,
#  <td class="lastTd">4.571</td>,
#  <td class="lastTd">4.576</td>,
#  <td class="lastTd">4.573</td>,
#  <td class="lastTd">4.577</td>,
#  <td class="lastTd">4.564</td>,
#  <td class="lastTd">4.559</td>,
#  <td class="lastTd">4.561</td>,
#  <td class="lastTd">4.569</td>,
#  <td class="lastTd">4.571</td>]

# %%
# Out:
# <td class="lastTd">4.59</td>

# %%
# Out:
# ([<td colspan="3" id="currencyTitle">人民幣(CNY)</td>,
#   <td width="215">日期</td>,
#   <td>買入</td>,
#   <td class="lastTd">賣出</td>,
#   <td class="itemTtitle">2017-10-31</td>,
#   <td>4.522</td>,
#   <td class="lastTd">4.572</td>,
#   <td class="itemTtitle">2017-11-01</td>,
#   <td>4.54</td>,
#   <td class="lastTd">4.59</td>,
#   <td class="itemTtitle">2017-11-02</td>,
#   <td>4.541</td>,
#   <td class="lastTd">4.591</td>,
#   <td class="itemTtitle">2017-11-03</td>,
#   <td>4.521</td>,
#   <td class="lastTd">4.571</td>,
#   <td class="itemTtitle">2017-11-06</td>,
#   <td>4.526</td>,
#   <td class="lastTd">4.576</td>,
#   <td class="itemTtitle">2017-11-07</td>,
#   <td>4.523</td>,
#   <td class="lastTd">4.573</td>,
#   <td class="itemTtitle">2017-11-08</td>,
#   <td>4.527</td>,
#   <td class="lastTd">4.577</td>,
#   <td class="itemTtitle">2017-11-09</td>,
#   <td>4.514</td>,
#   <td class="lastTd">4.564</td>,
#   <td class="itemTtitle">2017-11-10</td>,
#   <td>4.509</td>,
# ...

# %%
list=[]
i=3
for k in range(13):
    tds=tblh[i*k+3].get_text()
    list.append(tds)

print(list)
# Out:
# ['賣出', '4.572', '4.59', '4.591', '4.571', '4.576', '4.573', '4.577', '4.564', '4.559', '4.561', '4.569', '4.571']

# %%
DF['DATE']=pd.to_datetime(DF.DATE,format='%Y%m')
DF=DF.set_index(DF['DATE'],drop=True)
del DF['DATE']
DF.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-10d9d9505ac1> in <module>()
# ----> 1 DF['DATE']=pd.to_datetime(DF.DATE,format='%Y%m')
#       2 DF=DF.set_index(DF['DATE'],drop=True)
#       3 del DF['DATE']
#       4 DF.head()
#
# NameError: name 'DF' is not defined

# %%
region = ['USD','EUR','GBP','ZAR','JPY']
l=0
l1=1
ER ={}
for i in region:
    
    ER[i+'_B'] = DF.iloc[:,l]
    ER[i+'_S'] = DF.iloc[:,l1]
    l=l+2
    l1=l1+2
    print(ER[i+'_B'].head(),ER[i+'_S'].head())
# Out:
# DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# 1980-03-01   NaN
# 1980-04-01   NaN
# 1980-05-01   NaN
# Name: 美金_B, dtype: float64 DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# 1980-03-01   NaN
# 1980-04-01   NaN
# 1980-05-01   NaN
# Name: 美金_S, dtype: float64
# DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# 1980-03-01   NaN
# 1980-04-01   NaN
# 1980-05-01   NaN
# Name: 歐元_B, dtype: float64 DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# 1980-03-01   NaN
# 1980-04-01   NaN
# 1980-05-01   NaN
# Name: 歐元_S, dtype: float64
# DATE
# 1980-01-01    81.44
# 1980-02-01    82.06
# 1980-03-01    78.32
# 1980-04-01    81.58
# 1980-05-01    84.52
# Name: 英鎊_B, dtype: float64 DATE
# 1980-01-01    81.84
# 1980-02-01    82.50
# 1980-03-01    78.71
# 1980-04-01    81.99
# 1980-05-01    84.94
# Name: 英鎊_S, dtype: float64
# DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# 1980-03-01   NaN
# 1980-04-01   NaN
# 1980-05-01   NaN
# Name: 南非幣_B, dtype: float64 DATE
# 1980-01-01   NaN
# 1980-02-01   NaN
# ...

# %%
for i in region:   
    ER['d_'+i] = ER[i+'_S'] - ER[i+'_B']
    print(ER['d_'+i])
# Out:
# DATE
# 1980-01-01    NaN
# 1980-02-01    NaN
# 1980-03-01    NaN
# 1980-04-01    NaN
# 1980-05-01    NaN
# 1980-06-01    NaN
# 1980-07-01    NaN
# 1980-08-01    NaN
# 1980-09-01    NaN
# 1980-10-01    NaN
# 1980-11-01    NaN
# 1980-12-01    NaN
# 1981-01-01    NaN
# 1981-02-01    NaN
# 1981-03-01    NaN
# 1981-04-01    NaN
# 1981-05-01    NaN
# 1981-06-01    NaN
# 1981-07-01    NaN
# 1981-08-01    NaN
# 1981-09-01    NaN
# 1981-10-01    NaN
# 1981-11-01    NaN
# 1981-12-01    NaN
# 1982-01-01    NaN
# 1982-02-01    NaN
# 1982-03-01    NaN
# 1982-04-01    NaN
# 1982-05-01    NaN
# 1982-06-01    NaN
#              ...
# 2015-11-01    0.1
# 2015-12-01    0.1
# 2016-01-01    0.1
# 2016-02-01    0.1
# 2016-03-01    0.1
# 2016-04-01    0.1
# 2016-05-01    0.1
# 2016-06-01    0.1
# 2016-07-01    0.1
# 2016-08-01    0.1
# 2016-09-01    0.1
# 2016-10-01    0.1
# 2016-11-01    0.1
# 2016-12-01    0.1
# 2017-01-01    0.1
# 2017-02-01    0.1
# 2017-03-01    0.1
# 2017-04-01    0.1
# ...

# %%
close=ER['USD_S']

# %%
#平均移动均线的指标SMA
#不同權重，MA_Type: 0=SMA, 1=EMA, 2=WMA, 3=DEMA, 4=TEMA, 5=TRIMA, 6=KAMA, 7=MAMA, 8=T3 (Default=SMA)
SMA = talib.MA(close,12,matype=0)[-1]
EMA = talib.MA(close,12,matype=1)[-1]
WMA = talib.MA(close,12,matype=2)[-1]
DEMA = talib.MA(close,12,matype=3)[-1]
TEMA = talib.MA(close,12,matype=4)[-1]
plt.scatter('SMA',SMA)
plt.scatter('EMA',EMA)
plt.scatter('WMA',WMA)
plt.scatter('DEMA',DEMA)
plt.scatter('TEMA',TEMA)

# %%
#macd(DIF) = 12 天 EMA - 26 天 EMA， macdsignal(MACD) = 9 天 MACD的EMA ， macdhist(OSC) = MACD - MACD signal
macd, macdsignal, macdhist = talib.MACD(close, fastperiod=4, slowperiod=8, signalperiod=3)
plt.plot(macd)
plt.plot(macdsignal)
plt.plot(macdhist)

# %%
#交易策略
record=pd.Series('NA',index=pd.date_range('1/1/1980',periods=len(macd), freq='M'))
pre=pd.Series('NA',index=pd.date_range('1/1/1980',periods=len(macd), freq='M'))
i=0
for i in range(len(macd)):
    if macd[i]>macdsignal[i] and macd[i]>0:
        record[i]=close[i]
        pre[i]='Buy'
    if macd[i]<macdsignal[i] and macd[i]<0:
        record[i]=close[i]
        pre[i]='Sell'
        i=i+1
print(record, pre)
# Out:
# 1980-01-31       NA
# 1980-02-29       NA
# 1980-03-31       NA
# 1980-04-30       NA
# 1980-05-31       NA
# 1980-06-30       NA
# 1980-07-31       NA
# 1980-08-31       NA
# 1980-09-30       NA
# 1980-10-31       NA
# 1980-11-30       NA
# 1980-12-31       NA
# 1981-01-31       NA
# 1981-02-28       NA
# 1981-03-31       NA
# 1981-04-30       NA
# 1981-05-31       NA
# 1981-06-30       NA
# 1981-07-31       NA
# 1981-08-31       NA
# 1981-09-30       NA
# 1981-10-31       NA
# 1981-11-30       NA
# 1981-12-31       NA
# 1982-01-31       NA
# 1982-02-28       NA
# 1982-03-31       NA
# 1982-04-30       NA
# 1982-05-31       NA
# 1982-06-30       NA
#               ...
# 2015-11-30    32.65
# 2015-12-31       NA
# 2016-01-31    33.47
# 2016-02-29       NA
# 2016-03-31       NA
# 2016-04-30       NA
# 2016-05-31       NA
# 2016-06-30    32.33
# 2016-07-31    31.97
# 2016-08-31    31.77
# 2016-09-30    31.41
# 2016-10-31    31.61
# 2016-11-30       NA
# 2016-12-31       NA
# ...

# %%
df2={'price':record, 'move':pre}
df2=pd.DataFrame(df2)
df2
# Out:
#             price  move
# 1980-01-31     NA    NA
# 1980-02-29     NA    NA
# 1980-03-31     NA    NA
# 1980-04-30     NA    NA
# 1980-05-31     NA    NA
# 1980-06-30     NA    NA
# 1980-07-31     NA    NA
# 1980-08-31     NA    NA
# 1980-09-30     NA    NA
# 1980-10-31     NA    NA
# 1980-11-30     NA    NA
# 1980-12-31     NA    NA
# 1981-01-31     NA    NA
# 1981-02-28     NA    NA
# 1981-03-31     NA    NA
# 1981-04-30     NA    NA
# 1981-05-31     NA    NA
# 1981-06-30     NA    NA
# 1981-07-31     NA    NA
# 1981-08-31     NA    NA
# 1981-09-30     NA    NA
# 1981-10-31     NA    NA
# 1981-11-30     NA    NA
# 1981-12-31     NA    NA
# 1982-01-31     NA    NA
# 1982-02-28     NA    NA
# 1982-03-31     NA    NA
# 1982-04-30     NA    NA
# 1982-05-31     NA    NA
# 1982-06-30     NA    NA
# ...           ...   ...
# 2015-11-30  32.65   Buy
# 2015-12-31     NA    NA
# 2016-01-31  33.47   Buy
# 2016-02-29     NA    NA
# 2016-03-31     NA    NA
# 2016-04-30     NA    NA
# ...

# %%
import csv
df2.to_csv(r"C:\Users\yanghch\Desktop\data_df.csv")
pd.read_csv(r"C:\Users\yanghch\Desktop\data_df.csv")
# Out:
#      Unnamed: 0  price  move
# 0    1980-01-31    NaN   NaN
# 1    1980-02-29    NaN   NaN
# 2    1980-03-31    NaN   NaN
# 3    1980-04-30    NaN   NaN
# 4    1980-05-31    NaN   NaN
# 5    1980-06-30    NaN   NaN
# 6    1980-07-31    NaN   NaN
# 7    1980-08-31    NaN   NaN
# 8    1980-09-30    NaN   NaN
# 9    1980-10-31    NaN   NaN
# 10   1980-11-30    NaN   NaN
# 11   1980-12-31    NaN   NaN
# 12   1981-01-31    NaN   NaN
# 13   1981-02-28    NaN   NaN
# 14   1981-03-31    NaN   NaN
# 15   1981-04-30    NaN   NaN
# 16   1981-05-31    NaN   NaN
# 17   1981-06-30    NaN   NaN
# 18   1981-07-31    NaN   NaN
# 19   1981-08-31    NaN   NaN
# 20   1981-09-30    NaN   NaN
# 21   1981-10-31    NaN   NaN
# 22   1981-11-30    NaN   NaN
# 23   1981-12-31    NaN   NaN
# 24   1982-01-31    NaN   NaN
# 25   1982-02-28    NaN   NaN
# 26   1982-03-31    NaN   NaN
# 27   1982-04-30    NaN   NaN
# 28   1982-05-31    NaN   NaN
# 29   1982-06-30    NaN   NaN
# ..          ...    ...   ...
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels import regression

# %%
raw=r'C:\Users\yanghch\Google 雲端硬碟\INER\TFP\TFP_DATA\DATA_T.xlsx'
GDP_df=pd.read_excel(raw,sheet_name='GDP_T')
K_df=pd.read_excel(raw,sheet_name='實質固定資本存量淨額_T')
L_df=pd.read_excel(raw,sheet_name='就業人數_T')
print(GDP_df,K_df,L_df)
# Out:
#     實質附加價值\n2008SNA(T=100)      2            3         4             5  \
# 0                      NaN     礦業  食品、飲料、菸草製造業  紡織及成衣服飾品  皮革、毛皮及其製品製造業
# 1                     85.0  47937       177749    184570         26215
# 2                     86.0  42321       169798    183122         25132
# 3                     87.0  38012       167159    185873         20862
# 4                     88.0  35670       168029    184498         22344
# 5                     89.0  33227       172897    180918         19685
# 6                     90.0  29924       182867    160871         17486
# 7                     91.0  29054       146538    162599         19973
# 8                     92.0  22203       148713    151308         19838
# 9                     93.0  21557       147202    146918         20750
# 10                    94.0  19093       150568    128414         21044
# 11                    95.0  15330       148737    123790         20026
# ...

# %%
GDP_df=GDP_df.fillna(value=0) 
K_df=K_df.fillna(value=0)
L_df=L_df.fillna(value=0)

# %%
GDP = np.asarray(GDP_df.iloc[1:21,2])
K= np.asarray(K_df.iloc[1:21,2])
L = np.asarray(L_df.iloc[1:21,2])
print(GDP,K,L)
# Out:
# [177749 169798 167159 168029 172897 182867 146538 148713 147202 150568
#  148737 156403 157485 163589 169135 178949 183637 180065 181526 179892] [267739.01012241055 280585.22583720647 279556.3708655064
#  298650.38711927447 331162.6174973362 342224.161773517 355852.6491101491
#  359202.8181894124 358228.71550757 376457.55676554074 374292.6537574948
#  374406.1537676127 362950.86489855207 361021.39358466136 364349.0137124367
#  376124.53727410163 390213.03558788716 425517.70232884685
#  444894.1977193768 473258.57652594324] [144.472 148.234 151.187 148.382 144.431 138.763 147.159 149.206 147.031
#  148.404 159.849 151.254 153.576 158.36970000000002 167.0791
#  163.38700000000003 165 167 172 176]

# %%
from sklearn.linear_model import LinearRegression 
lm = LinearRegression()
lm.fit(x=L.reshape(-1, 1),y=GDP)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-a9aaa94a5226> in <module>()
#       1 from sklearn.linear_model import LinearRegression
#       2 lm = LinearRegression()
# ----> 3 lm.fit(x=L.reshape(-1, 1),y=GDP)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'reshape'

# %%
X=sm.add_constant(K)
model=sm.OLS(GDP,X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-4d849240877c> in <module>()
#       1 X=sm.add_constant(K)
# ----> 2 model=sm.OLS(GDP,X)
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# ...
